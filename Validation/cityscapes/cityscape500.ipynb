# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q /content/drive/MyDrive/cityscapes.zip -d /content/

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.179-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.16.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.15-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.179-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 28.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 110.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 92.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 105.0 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.15-py3-none-any.whl (28 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.179 ultralytics-thop-2.0.15

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 47.6/112.6 GB disk)

# %%
from ultralytics import YOLO

# %%
from IPython.display import Image

# %%
# validate Yolov8n on coco8 val

# !yolo val model=/content/best.pt data=/content/config.yaml
# Out:
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-seg summary (fused): 85 layers, 3,258,259 parameters, 0 gradients, 12.0 GFLOPs
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% 755k/755k [00:00<00:00, 24.3MB/s]
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 180.8±18.2 MB/s, size: 2399.0 KB)
# val: Scanning /content/cityscapes/val/labels... 156 images, 0 backgrounds, 0 corrupt: 100% 156/156 [00:01<00:00, 94.66it/s]
# val: New cache created: /content/cityscapes/val/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0% 0/10 [00:00<?, ?it/s]WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 10/10 [00:08<00:00,  1.12it/s]
#                    all        156        163       0.92      0.853      0.878      0.153     0.0188     0.0184    0.00349   0.000349
# Speed: 1.1ms preprocess, 5.2ms inference, 0.0ms loss, 7.5ms postprocess per image
# Results saved to runs/segment/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# predict / run inference on an image with Yolov8n

# !yolo predict model=/content/best.pt source=/content/cityscapes/val/images
# Out:
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-seg summary (fused): 85 layers, 3,258,259 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/156 /content/cityscapes/val/images/frankfurt_000000_000294.png: 320x640 1 road, 43.5ms
# image 2/156 /content/cityscapes/val/images/frankfurt_000000_000576.png: 320x640 1 road, 8.0ms
# image 3/156 /content/cityscapes/val/images/frankfurt_000000_001016.png: 320x640 1 road, 7.9ms
# image 4/156 /content/cityscapes/val/images/frankfurt_000000_001236.png: 320x640 1 road, 7.9ms
# image 5/156 /content/cityscapes/val/images/frankfurt_000000_001751.png: 320x640 1 road, 7.7ms
# image 6/156 /content/cityscapes/val/images/frankfurt_000000_002196.png: 320x640 1 road, 7.8ms
# image 7/156 /content/cityscapes/val/images/frankfurt_000000_002963.png: 320x640 1 road, 7.7ms
# image 8/156 /content/cityscapes/val/images/frankfurt_000000_003025.png: 320x640 1 road, 7.8ms
# image 9/156 /content/cityscapes/val/images/frankfurt_000000_003357.png: 320x640 2 roads, 7.7ms
# image 10/156 /content/cityscapes/val/images/frankfurt_000000_003920.png: 320x640 1 road, 7.7ms
# image 11/156 /content/cityscapes/val/images/frankfurt_000000_004617.png: 320x640 1 road, 7.7ms
# image 12/156 /content/cityscapes/val/images/frankfurt_000000_005543.png: 320x640 1 road, 7.5ms
# image 13/156 /content/cityscapes/val/images/frankfurt_000000_005898.png: 320x640 1 road, 7.7ms
# image 14/156 /content/cityscapes/val/images/frankfurt_000000_006589.png: 320x640 1 road, 7.6ms
# image 15/156 /content/cityscapes/val/images/frankfurt_000000_007365.png: 320x640 1 road, 7.6ms
# image 16/156 /content/cityscapes/val/images/frankfurt_000000_008206.png: 320x640 3 roads, 7.8ms
# image 17/156 /content/cityscapes/val/images/frankfurt_000000_008451.png: 320x640 1 road, 7.6ms
# image 18/156 /content/cityscapes/val/images/frankfurt_000000_009291.png: 320x640 1 road, 7.6ms
# image 19/156 /content/cityscapes/val/images/frankfurt_000000_009561.png: 320x640 1 road, 7.8ms
# image 20/156 /content/cityscapes/val/images/frankfurt_000000_009688.png: 320x640 1 road, 7.7ms
# image 21/156 /content/cityscapes/val/images/frankfurt_000000_009969.png: 320x640 1 road, 7.6ms
# image 22/156 /content/cityscapes/val/images/frankfurt_000000_010351.png: 320x640 1 road, 7.7ms
# image 23/156 /content/cityscapes/val/images/frankfurt_000000_010763.png: 320x640 1 road, 7.7ms
# image 24/156 /content/cityscapes/val/images/frankfurt_000000_011007.png: 320x640 1 road, 7.7ms
# image 25/156 /content/cityscapes/val/images/frankfurt_000000_011074.png: 320x640 2 roads, 7.7ms
# image 26/156 /content/cityscapes/val/images/frankfurt_000000_011461.png: 320x640 1 road, 7.7ms
# image 27/156 /content/cityscapes/val/images/frankfurt_000000_011810.png: 320x640 1 road, 7.7ms
# image 28/156 /content/cityscapes/val/images/frankfurt_000000_012009.png: 320x640 1 road, 8.4ms
# image 29/156 /content/cityscapes/val/images/frankfurt_000000_012121.png: 320x640 1 road, 12.7ms
# image 30/156 /content/cityscapes/val/images/frankfurt_000000_012868.png: 320x640 1 road, 7.7ms
# image 31/156 /content/cityscapes/val/images/frankfurt_000000_013067.png: 320x640 1 road, 7.7ms
# image 32/156 /content/cityscapes/val/images/frankfurt_000000_013240.png: 320x640 1 road, 7.6ms
# image 33/156 /content/cityscapes/val/images/frankfurt_000000_013382.png: 320x640 1 road, 7.7ms
# image 34/156 /content/cityscapes/val/images/frankfurt_000000_013942.png: 320x640 1 road, 7.7ms
# image 35/156 /content/cityscapes/val/images/frankfurt_000000_014480.png: 320x640 1 road, 7.6ms
# image 36/156 /content/cityscapes/val/images/frankfurt_000000_015389.png: 320x640 1 road, 7.7ms
# image 37/156 /content/cityscapes/val/images/frankfurt_000000_015676.png: 320x640 1 road, 7.7ms
# image 38/156 /content/cityscapes/val/images/frankfurt_000000_016005.png: 320x640 2 roads, 7.8ms
# image 39/156 /content/cityscapes/val/images/frankfurt_000000_016286.png: 320x640 1 road, 7.8ms
# image 40/156 /content/cityscapes/val/images/frankfurt_000000_017228.png: 320x640 1 road, 7.7ms
# image 41/156 /content/cityscapes/val/images/frankfurt_000000_017476.png: 320x640 1 road, 7.7ms
# image 42/156 /content/cityscapes/val/images/frankfurt_000000_018797.png: 320x640 1 road, 7.6ms
# image 43/156 /content/cityscapes/val/images/frankfurt_000000_019607.png: 320x640 1 road, 8.0ms
# image 44/156 /content/cityscapes/val/images/frankfurt_000000_020215.png: 320x640 1 road, 7.8ms
# image 45/156 /content/cityscapes/val/images/frankfurt_000000_020321.png: 320x640 1 road, 7.7ms
# image 46/156 /content/cityscapes/val/images/frankfurt_000000_020880.png: 320x640 1 road, 7.7ms
# image 47/156 /content/cityscapes/val/images/frankfurt_000000_021667.png: 320x640 1 road, 7.8ms
# image 48/156 /content/cityscapes/val/images/frankfurt_000000_021879.png: 320x640 1 road, 7.8ms
# image 49/156 /content/cityscapes/val/images/frankfurt_000000_022254.png: 320x640 1 road, 7.7ms
# image 50/156 /content/cityscapes/val/images/frankfurt_000000_022797.png: 320x640 1 road, 10.9ms
# image 51/156 /content/cityscapes/val/images/frankfurt_000001_000538.png: 320x640 1 road, 7.7ms
# image 52/156 /content/cityscapes/val/images/frankfurt_000001_001464.png: 320x640 1 road, 7.8ms
# image 53/156 /content/cityscapes/val/images/frankfurt_000001_002512.png: 320x640 1 road, 7.8ms
# image 54/156 /content/cityscapes/val/images/frankfurt_000001_002646.png: 320x640 1 road, 7.8ms
# image 55/156 /content/cityscapes/val/images/frankfurt_000001_002759.png: 320x640 1 road, 8.4ms
# image 56/156 /content/cityscapes/val/images/frankfurt_000001_003056.png: 320x640 1 road, 8.1ms
# image 57/156 /content/cityscapes/val/images/frankfurt_000001_003588.png: 320x640 1 road, 7.9ms
# image 58/156 /content/cityscapes/val/images/frankfurt_000001_004327.png: 320x640 1 road, 7.7ms
# image 59/156 /content/cityscapes/val/images/frankfurt_000001_004736.png: 320x640 1 road, 7.7ms
# image 60/156 /content/cityscapes/val/images/frankfurt_000001_004859.png: 320x640 1 road, 8.0ms
# image 61/156 /content/cityscapes/val/images/frankfurt_000001_005184.png: 320x640 1 road, 7.8ms
# image 62/156 /content/cityscapes/val/images/frankfurt_000001_005410.png: 320x640 1 road, 7.7ms
# image 63/156 /content/cityscapes/val/images/frankfurt_000001_005703.png: 320x640 1 road, 7.7ms
# image 64/156 /content/cityscapes/val/images/frankfurt_000001_005898.png: 320x640 1 road, 7.7ms
# image 65/156 /content/cityscapes/val/images/frankfurt_000001_007285.png: 320x640 1 road, 8.8ms
# image 66/156 /content/cityscapes/val/images/frankfurt_000001_007407.png: 320x640 1 road, 7.7ms
# image 67/156 /content/cityscapes/val/images/frankfurt_000001_007622.png: 320x640 1 road, 7.8ms
# image 68/156 /content/cityscapes/val/images/frankfurt_000001_007857.png: 320x640 2 roads, 7.8ms
# image 69/156 /content/cityscapes/val/images/frankfurt_000001_007973.png: 320x640 1 road, 7.8ms
# image 70/156 /content/cityscapes/val/images/frankfurt_000001_008200.png: 320x640 1 road, 12.6ms
# image 71/156 /content/cityscapes/val/images/frankfurt_000001_008688.png: 320x640 2 roads, 7.8ms
# image 72/156 /content/cityscapes/val/images/frankfurt_000001_009058.png: 320x640 1 road, 7.8ms
# image 73/156 /content/cityscapes/val/images/frankfurt_000001_009504.png: 320x640 2 roads, 7.8ms
# image 74/156 /content/cityscapes/val/images/frankfurt_000001_009854.png: 320x640 1 road, 7.7ms
# image 75/156 /content/cityscapes/val/images/frankfurt_000001_010156.png: 320x640 1 road, 7.7ms
# image 76/156 /content/cityscapes/val/images/frankfurt_000001_010444.png: 320x640 (no detections), 7.6ms
# image 77/156 /content/cityscapes/val/images/frankfurt_000001_010600.png: 320x640 1 road, 7.7ms
# image 78/156 /content/cityscapes/val/images/frankfurt_000001_010830.png: 320x640 1 road, 10.9ms
# image 79/156 /content/cityscapes/val/images/frankfurt_000001_011162.png: 320x640 1 road, 9.6ms
# image 80/156 /content/cityscapes/val/images/frankfurt_000001_011715.png: 320x640 1 road, 11.1ms
# image 81/156 /content/cityscapes/val/images/frankfurt_000001_011835.png: 320x640 (no detections), 10.4ms
# image 82/156 /content/cityscapes/val/images/frankfurt_000001_012038.png: 320x640 1 road, 9.4ms
# image 83/156 /content/cityscapes/val/images/frankfurt_000001_012519.png: 320x640 1 road, 14.2ms
# image 84/156 /content/cityscapes/val/images/frankfurt_000001_012699.png: 320x640 1 road, 9.3ms
# image 85/156 /content/cityscapes/val/images/frankfurt_000001_012738.png: 320x640 1 road, 9.0ms
# image 86/156 /content/cityscapes/val/images/frankfurt_000001_012870.png: 320x640 1 road, 10.4ms
# image 87/156 /content/cityscapes/val/images/frankfurt_000001_013016.png: 320x640 (no detections), 13.0ms
# image 88/156 /content/cityscapes/val/images/frankfurt_000001_013496.png: 320x640 1 road, 9.6ms
# image 89/156 /content/cityscapes/val/images/frankfurt_000001_013710.png: 320x640 1 road, 11.4ms
# image 90/156 /content/cityscapes/val/images/frankfurt_000001_014221.png: 320x640 1 road, 9.6ms
# image 91/156 /content/cityscapes/val/images/frankfurt_000001_014406.png: 320x640 1 road, 9.6ms
# image 92/156 /content/cityscapes/val/images/frankfurt_000001_014565.png: 320x640 1 road, 9.4ms
# image 93/156 /content/cityscapes/val/images/frankfurt_000001_014741.png: 320x640 1 road, 9.2ms
# image 94/156 /content/cityscapes/val/images/frankfurt_000001_015091.png: 320x640 1 road, 9.0ms
# image 95/156 /content/cityscapes/val/images/frankfurt_000001_015328.png: 320x640 1 road, 9.0ms
# image 96/156 /content/cityscapes/val/images/frankfurt_000001_015768.png: 320x640 2 roads, 9.1ms
# image 97/156 /content/cityscapes/val/images/frankfurt_000001_016029.png: 320x640 1 road, 12.9ms
# image 98/156 /content/cityscapes/val/images/frankfurt_000001_016273.png: 320x640 1 road, 9.2ms
# image 99/156 /content/cityscapes/val/images/frankfurt_000001_016462.png: 320x640 1 road, 13.0ms
# image 100/156 /content/cityscapes/val/images/frankfurt_000001_060906.png: 320x640 1 road, 13.3ms
# image 101/156 /content/cityscapes/val/images/frankfurt_000001_061682.png: 320x640 2 roads, 13.4ms
# image 102/156 /content/cityscapes/val/images/frankfurt_000001_061763.png: 320x640 1 road, 7.7ms
# image 103/156 /content/cityscapes/val/images/frankfurt_000001_062016.png: 320x640 1 road, 7.7ms
# image 104/156 /content/cityscapes/val/images/frankfurt_000001_062250.png: 320x640 1 road, 7.7ms
# image 105/156 /content/cityscapes/val/images/frankfurt_000001_062396.png: 320x640 1 road, 7.7ms
# image 106/156 /content/cityscapes/val/images/frankfurt_000001_062509.png: 320x640 1 road, 8.0ms
# image 107/156 /content/cityscapes/val/images/frankfurt_000001_062653.png: 320x640 1 road, 7.8ms
# image 108/156 /content/cityscapes/val/images/frankfurt_000001_062793.png: 320x640 1 road, 7.6ms
# image 109/156 /content/cityscapes/val/images/frankfurt_000001_063045.png: 320x640 1 road, 7.8ms
# image 110/156 /content/cityscapes/val/images/frankfurt_000001_064130.png: 320x640 1 road, 7.9ms
# image 111/156 /content/cityscapes/val/images/frankfurt_000001_064305.png: 320x640 1 road, 7.7ms
# image 112/156 /content/cityscapes/val/images/frankfurt_000001_064651.png: 320x640 1 road, 7.8ms
# image 113/156 /content/cityscapes/val/images/frankfurt_000001_064798.png: 320x640 1 road, 7.7ms
# image 114/156 /content/cityscapes/val/images/frankfurt_000001_064925.png: 320x640 1 road, 7.5ms
# image 115/156 /content/cityscapes/val/images/frankfurt_000001_065160.png: 320x640 1 road, 7.7ms
# image 116/156 /content/cityscapes/val/images/frankfurt_000001_065617.png: 320x640 1 road, 7.8ms
# image 117/156 /content/cityscapes/val/images/frankfurt_000001_065850.png: 320x640 1 road, 7.7ms
# image 118/156 /content/cityscapes/val/images/frankfurt_000001_066092.png: 320x640 1 road, 7.6ms
# image 119/156 /content/cityscapes/val/images/frankfurt_000001_066438.png: 320x640 1 road, 7.8ms
# image 120/156 /content/cityscapes/val/images/frankfurt_000001_066574.png: 320x640 3 roads, 7.9ms
# image 121/156 /content/cityscapes/val/images/frankfurt_000001_066832.png: 320x640 2 roads, 7.8ms
# image 122/156 /content/cityscapes/val/images/frankfurt_000001_067092.png: 320x640 1 road, 7.9ms
# image 123/156 /content/cityscapes/val/images/frankfurt_000001_067178.png: 320x640 1 road, 7.7ms
# image 124/156 /content/cityscapes/val/images/frankfurt_000001_067295.png: 320x640 1 road, 7.8ms
# image 125/156 /content/cityscapes/val/images/frankfurt_000001_067474.png: 320x640 1 road, 7.7ms
# image 126/156 /content/cityscapes/val/images/frankfurt_000001_067735.png: 320x640 1 road, 7.9ms
# image 127/156 /content/cityscapes/val/images/frankfurt_000001_068063.png: 320x640 1 road, 7.7ms
# image 128/156 /content/cityscapes/val/images/frankfurt_000001_068208.png: 320x640 1 road, 7.6ms
# image 129/156 /content/cityscapes/val/images/frankfurt_000001_068682.png: 320x640 1 road, 7.9ms
# image 130/156 /content/cityscapes/val/images/frankfurt_000001_068772.png: 320x640 1 road, 7.8ms
# image 131/156 /content/cityscapes/val/images/frankfurt_000001_069633.png: 320x640 1 road, 7.7ms
# image 132/156 /content/cityscapes/val/images/frankfurt_000001_070099.png: 320x640 1 road, 7.6ms
# image 133/156 /content/cityscapes/val/images/frankfurt_000001_071288.png: 320x640 1 road, 7.6ms
# image 134/156 /content/cityscapes/val/images/frankfurt_000001_071781.png: 320x640 1 road, 7.7ms
# image 135/156 /content/cityscapes/val/images/frankfurt_000001_072155.png: 320x640 1 road, 7.7ms
# image 136/156 /content/cityscapes/val/images/frankfurt_000001_072295.png: 320x640 1 road, 7.7ms
# image 137/156 /content/cityscapes/val/images/frankfurt_000001_073088.png: 320x640 1 road, 7.9ms
# image 138/156 /content/cityscapes/val/images/frankfurt_000001_073243.png: 320x640 1 road, 8.2ms
# image 139/156 /content/cityscapes/val/images/frankfurt_000001_073464.png: 320x640 2 roads, 7.9ms
# image 140/156 /content/cityscapes/val/images/frankfurt_000001_073911.png: 320x640 1 road, 7.7ms
# image 141/156 /content/cityscapes/val/images/frankfurt_000001_075296.png: 320x640 1 road, 8.1ms
# image 142/156 /content/cityscapes/val/images/frankfurt_000001_075984.png: 320x640 1 road, 7.6ms
# image 143/156 /content/cityscapes/val/images/frankfurt_000001_076502.png: 320x640 1 road, 8.3ms
# image 144/156 /content/cityscapes/val/images/frankfurt_000001_077092.png: 320x640 1 road, 11.0ms
# image 145/156 /content/cityscapes/val/images/frankfurt_000001_077233.png: 320x640 1 road, 9.6ms
# image 146/156 /content/cityscapes/val/images/frankfurt_000001_077434.png: 320x640 1 road, 8.5ms
# image 147/156 /content/cityscapes/val/images/frankfurt_000001_078803.png: 320x640 1 road, 7.9ms
# image 148/156 /content/cityscapes/val/images/frankfurt_000001_079206.png: 320x640 1 road, 7.7ms
# image 149/156 /content/cityscapes/val/images/frankfurt_000001_080091.png: 320x640 1 road, 7.8ms
# image 150/156 /content/cityscapes/val/images/frankfurt_000001_080391.png: 320x640 1 road, 7.9ms
# image 151/156 /content/cityscapes/val/images/frankfurt_000001_080830.png: 320x640 1 road, 7.7ms
# image 152/156 /content/cityscapes/val/images/frankfurt_000001_082087.png: 320x640 1 road, 7.8ms
# image 153/156 /content/cityscapes/val/images/frankfurt_000001_082466.png: 320x640 1 road, 7.6ms
# image 154/156 /content/cityscapes/val/images/frankfurt_000001_083029.png: 320x640 1 road, 9.2ms
# image 155/156 /content/cityscapes/val/images/frankfurt_000001_083199.png: 320x640 1 road, 7.9ms
# image 156/156 /content/cityscapes/val/images/frankfurt_000001_083852.png: 320x640 1 road, 8.2ms
# Speed: 2.1ms preprocess, 8.6ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# predict / run inference on an image with Yolov8n

# !yolo predict model=/content/best.pt source=/content/cityscapes/train/images/10_00000_4.png
# Out:
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-seg summary (fused): 85 layers, 3,258,259 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/1 /content/cityscapes/train/images/10_00000_4.png: 640x640 1 road, 9.4ms
# Speed: 2.4ms preprocess, 9.4ms inference, 195.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
  Image(filename = '/content/runs/segment/val/confusion_matrix.png' , width=600)

# %%
Image(filename = '/content/runs/segment/val/BoxF1_curve.png' , width=600)

# %%
Image(filename = '/content/runs/segment/val/BoxPR_curve.png' , width=600)

# %%
import shutil

# Create a zip file of the 'runs' directory
shutil.make_archive('/content/runs', 'zip', '/content/runs')
# Out:
# '/content/runs.zip'

# %%
from google.colab import files

# Download the newly created zip file
files.download('/content/runs.zip')
