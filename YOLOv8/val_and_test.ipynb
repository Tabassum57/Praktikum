# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q /content/drive/MyDrive/Data.zip -d /content/

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 28.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 117.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 94.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 103.3 MB/s eta 0:00:00
# ...

# %%
from IPython.display import Image

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.178 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 48.5/112.6 GB disk)

# %%
import locale
locale.getpreferredencoding = lambda: 'UTF-8'

# %%
# !export LC_ALL=C.UTF-8
# !export LANG=C.UTF-8

# %%
# validate Yolov8n on coco8 val

# !yolo val model=/content/best.pt data=/content/config.yaml
# Out:
# Ultralytics 8.3.178 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-seg summary (fused): 85 layers, 3,258,259 parameters, 0 gradients, 12.0 GFLOPs
# ...
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 116.3±36.1 MB/s, size: 617.2 KB)
# val: Scanning /content/Data/val/labels... 1199 images, 37 backgrounds, 0 corrupt: 100% 1200/1200 [00:04<00:00, 259.16it/s]
# val: New cache created: /content/Data/val/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0% 0/75 [00:00<?, ?it/s]WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# ...

# %%
# predict / run inference on an image with Yolov8n

# !yolo predict model=/content/best.pt source=/content/Data/val
# Out:
# Ultralytics 8.3.178 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-seg summary (fused): 85 layers, 3,258,259 parameters, 0 gradients, 12.0 GFLOPs
#
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/cfg/__init__.py", line 983, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py", line 555, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/predictor.py", line 247, in predict_cli
#     for _ in gen:  # sourcery skip: remove-empty-nested-block, noqa
# ...

# %%
# predict / run inference on an image with Yolov8n

# !yolo predict model=/content/best.pt source=/content/Data/val/images
# Out:
# Ultralytics 8.3.178 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-seg summary (fused): 85 layers, 3,258,259 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/1200 /content/Data/val/images/120_00000_321.png: 640x640 1 road, 13.9ms
# image 2/1200 /content/Data/val/images/120_00000_322.png: 640x640 1 road, 12.4ms
# image 3/1200 /content/Data/val/images/120_00000_323.png: 640x640 1 road, 10.4ms
# image 4/1200 /content/Data/val/images/120_00000_324.png: 640x640 1 road, 9.8ms
# image 5/1200 /content/Data/val/images/120_00000_325.png: 640x640 1 road, 9.6ms
# image 6/1200 /content/Data/val/images/120_00000_326.png: 640x640 1 road, 9.5ms
# image 7/1200 /content/Data/val/images/120_00000_327.png: 640x640 (no detections), 9.6ms
# image 8/1200 /content/Data/val/images/120_00000_328.png: 640x640 1 road, 9.4ms
# image 9/1200 /content/Data/val/images/120_00000_329.png: 640x640 3 roads, 10.1ms
# ...

# %%
# !yolo predict model=/content/best.pt source=/content/Data/test
# Out:
# Ultralytics 8.3.178 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-seg summary (fused): 85 layers, 3,258,259 parameters, 0 gradients, 12.0 GFLOPs
#
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/cfg/__init__.py", line 983, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py", line 555, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/predictor.py", line 247, in predict_cli
#     for _ in gen:  # sourcery skip: remove-empty-nested-block, noqa
# ...

# %%
# !yolo predict model=/content/best.pt source=/content/Data/test/images
# Out:
# Ultralytics 8.3.178 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-seg summary (fused): 85 layers, 3,258,259 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/480 /content/Data/test/images/120_00000_291.png: 640x640 3 roads, 9.4ms
# image 2/480 /content/Data/test/images/120_00000_292.png: 640x640 3 roads, 9.4ms
# image 3/480 /content/Data/test/images/120_00000_293.png: 640x640 1 road, 9.4ms
# image 4/480 /content/Data/test/images/120_00000_294.png: 640x640 1 road, 9.3ms
# image 5/480 /content/Data/test/images/120_00000_295.png: 640x640 1 road, 9.4ms
# image 6/480 /content/Data/test/images/120_00000_296.png: 640x640 1 road, 9.4ms
# image 7/480 /content/Data/test/images/120_00000_297.png: 640x640 1 road, 9.4ms
# image 8/480 /content/Data/test/images/120_00000_298.png: 640x640 1 road, 9.4ms
# image 9/480 /content/Data/test/images/120_00000_299.png: 640x640 1 road, 9.4ms
# image 10/480 /content/Data/test/images/120_00000_300.png: 640x640 1 road, 9.4ms
# ...

# %%
 Image(filename = '/content/runs/segment/predict2/120_00000_291.jpg' , width=600)

# %%
 Image(filename = '/content/runs/segment/val/confusion_matrix.png' , width=600)

# %%
import os
os.listdir('/content')
# Out:
# ['.config', 'config.yaml', 'runs', 'drive', 'best.pt', 'Data']

# %%
import shutil

# Create a zip file of the 'runs' directory
shutil.make_archive('/content/runs', 'zip', '/content/runs')
# Out:
# '/content/runs.zip'

# %%
from google.colab import files

# Download the newly created zip file
files.download('/content/runs.zip')
